# %% [markdown]
# <a name = 'head'></a>
#
# <hr class="dashed" style = 'color: #08CC5B'>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #6C07B2; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px; font-size: 14px; font-weight: 475; text-align: center; border-top: 2px solid #FFB83C; border-bottom: 2px solid #FFB83C;'  colspan="3"> |  <a href="#head">Top</a>  |  <a href="#historical">Historical Data</a>  |  <a href="#intraday">Intraday Frequency</a>   |  <a href="#time_period">Defining Time Period</a>  |  <a href="#indexes">Stock Indexes</a>  |  <a href="#commodities">Commodities</a>    <a href="#crypto">Cryptocurrencies</a>    <a href="#real_time">Real-Time Data</a>    </th>
# 		</tr>
# 	</table>
# </html>
#
# <hr class="dashed" style = 'color: #08CC5B'>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #A523FF; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px;; text-align: center; border-top: 2px solid #A523FF; border-bottom: 2px solid #FFB83C; font-size: 28px;' colspan="3">Finance APIs: FXCM</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 17px; font-weight: 525; background-color: #0F793C; padding: 8px; line-height: 1.5; color:white; border-radius: 3px; text-align: center;' colspan="3">|  <a href = 'https://www.fxcm.com/markets/'>FXCM Online</a>  |  <a href = 'https://tradingstation.fxcm.com/'>Account Login</a>  |</font></th>
# 		</tr>
# 	</table>
# </html>
#
# <html>
# 	<table>
# 	<tr style = 'border-top: 2px solid #08CC5B; background-color: #6C07B2; color: white; border-bottom: px solid #08CC5B;' colspan = 3>
# 			<td style = 'font-size: 13px; text-align: center;' colspan = 5><b>Evan Marie online</b>:  |  <a href = 'https://www.evanmarie.com/'>EvanMarie.com</a>|  <a href = 'mailto:evanmarie@proton.me'>EvanMarie@Proton.me</a>  |  <a href = 'https://www.linkedin.com/in/evanmarie/'>Linked In</a>  |  <a href = 'https://github.com/EvanMarie'>GitHub</a>   |  <a href = 'https://huggingface.co/EvanMarie'>Hugging Face</a>  |  <a href = 'https://sigmoid.social/@EvanMarie'>Mastadon</a>  |  <a href = 'https://jovian.ai/evanmarie'>Jovian.ai</a>  |  <a href = 'https://www.tiktok.com/@evanmarie_123'>TikTok</a>  |  <a href = 'https://www.codewars.com/users/EvanMarie'>CodeWars</a>  |  <b>Discord ⇨ ✨ EvanMarie ✨#6114</b>  |
# 			</td></tr>
# 	</table>
# </html>
#
# * Leader in online foreign exchange trading
# * Stocks and CFD trading (contract for difference, highly levered financial instrument)
# * Cryptocurrencies
#
# <html>
# 	<table style="width:50%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #FFB83C; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:black;border-radius: 3px;; text-align: center;' colspan="3"><b>Pros and Cons of FXCM</b></font></th>
# 		</tr>
# 	</table>
# </html>
# <font size = 4>Pros:<br></font>
# - Completely free with a demo account, which does not allow live trading<br>
# - Large datasets available for currencies, commodities, and indexes<br>
# - High frequency real-time data<br>
# - You can stream the high frequency real-time data<br>
# - Bid and ask prices are available<br>
# - fxcmpy is a powerful and professional wrapper package for python<br>
#
# <br>
#
# <font size = 4>Cons:<br></font>
# - Must register and make a demo account
# - marketing calls and emails to create a live account
# - demo accounts are not available in all countries, for example, the United State
# - No data for single stocks and bonds, no fundamentals
# - Only provide indexes, currencies, etc

# %%
from helpers_mardi_gras import *
import fxcmpy
import_all()
plt.style.use('mardi_gras.mplstyle')

# %%
# %%html
# <style>
# a:link {color: #FFB83C !important; font-weight: 600 !important;}
# a:visited {color: #FFB83C !important; font-weight: 600 !important;}
# </style>
# Out:
# <style>
# a:link {color: #FFB83C !important; font-weight: 600 !important;}
# a:visited {color: #FFB83C !important; font-weight: 600 !important;}
# </style>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 20px; font-weight: 525; background-color: #08CC5B; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: center;' colspan="3">FXCM: First Steps</font></th>
# 		</tr>
# 	</table>
# </html>

# %%
api_key = ''
api = fxcmpy.fxcmpy(access_token = api_key, log_level = 'error')

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #FFB83C; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:black;border-radius: 3px;; text-align: left;' colspan="3"><b># api is an fxcmpy object</b></font></th>
# 		</tr>
# 	</table>
# </html>

# %%
api

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #FFB83C; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:black;border-radius: 3px;; text-align: left;' colspan="3"><b><i># api.get_instruments()</b></i> - trading instruments</font></th>
# 		</tr>
# 	</table>
# </html>

# %%
pretty('api.get_instruments')
help(api.get_instruments)
# Out:
# <style type="text/css">
# #T_e800a .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_e800a tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_e800a tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_e800a">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e800a_row0_col0" class="data row0 col0" >api.get_instruments</td>
#     </tr>
#   </tbody>
# </table>
# Help on method get_instruments in module fxcmpy.fxcmpy:
#
# get_instruments() method of fxcmpy.fxcmpy.fxcmpy instance
#     Return the tradeable instruments of FXCM as a list.

# %%
trading_instruments = pd.Series(api.get_instruments())

# %%
see(trading_instruments.sample(10), '10 samples of trading instrumentsv')
# Out:
# <center><style type="text/css">
# #T_2ab55 tr {
#   background-color: #A523FF;
#   color: white;
#   font-size: 18px;
#   font-weight: 600;
#   text-align: left;
#   padding: 3px 30px 3px 50px;
# }
# #T_2ab55 td {
#   padding: 5px 10px 5px 10px;
#   width: autopx;
#   text-align: center;
# }
# </style>
# <table id="T_2ab55">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2ab55_row0_col0" class="data row0 col0" >10 samples of trading instrumentsv</td>
#     </tr>
#   </tbody>
# </table>
# <center><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>266</th>
#       <td>BTC/USD</td>
#     </tr>
#     <tr>
#       <th>151</th>
#       <td>CON.de</td>
#     </tr>
#     <tr>
#       <th>240</th>
#       <td>SPOT.us</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>CAD/CHF</td>
#     </tr>
#     <tr>
#       <th>203</th>
# ...

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #FFB83C; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:black;border-radius: 3px;; text-align: left;' colspan="3"><b><i>api.close()</i></b>- disconnect from the server</font></th>
# 		</tr>
# 	</table>
# </html>

# %%
# api.close()

# %% [markdown]
# <a name = 'historical'></a>
#
# <hr class="dashed" style = 'color: #08CC5B'>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #6C07B2; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px; font-size: 14px; font-weight: 475; text-align: center; border-top: 2px solid #FFB83C; border-bottom: 2px solid #FFB83C;'  colspan="3"> |  <a href="#head">Top</a>  |  <a href="#historical">Historical Data</a>  |  <a href="#intraday">Intraday Frequency</a>   |  <a href="#time_period">Defining Time Period</a>  |  <a href="#indexes">Stock Indexes</a>  |  <a href="#commodities">Commodities</a>    <a href="#crypto">Cryptocurrencies</a>    <a href="#real_time">Real-Time Data</a>    </th>
# 		</tr>
# 	</table>
# </html>
#
# <hr class="dashed" style = 'color: #08CC5B'>

# %% [markdown]
# <a name = 'head'></a>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #A523FF; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;; text-align: center; border-bottom: 1.5px solid white;' colspan="3"><font size = 6>Downloading Historical Data</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 525; background-color: #FFB83C; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: left;' colspan="3">-<i> get_candles()</i></font></th>
# 		</tr>
# 	</table>
# </html>

# %%
pretty('api.get_candles()')
help(api.get_candles)
# Out:
# <style type="text/css">
# #T_078ea .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_078ea tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_078ea tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_078ea">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_078ea_row0_col0" class="data row0 col0" >api.get_candles()</td>
#     </tr>
#   </tbody>
# </table>
# Help on method get_candles in module fxcmpy.fxcmpy:
#
# get_candles(instrument='', offer_id=None, period='H1', number=10, start=None, end=None, with_index=True, columns=[], stop=None) method of fxcmpy.fxcmpy.fxcmpy instance
#     Return historical data from the fxcm database as pandas.DataFrame.
#
#     Arguments:
#
#     instrument: string (default ''):
#         the instrument for which data is requested. For a list of all
# ...

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #FFB83C; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:black;border-radius: 3px;; text-align: left;' colspan="3"><b><i># hourly data by default</i></b></font></th>
# 		</tr>
# 	</table>
# </html>

# %%
pretty("api.get_candles('EUR/USD')")
api.get_candles('EUR/USD').head(5).style.format(precision = 4)
# Out:
# <style type="text/css">
# #T_f2d8e .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_f2d8e tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_f2d8e tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_f2d8e">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f2d8e_row0_col0" class="data row0 col0" >api.get_candles('EUR/USD')</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9ce4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ce4c_level0_col0" class="col_heading level0 col0" >bidopen</th>
#       <th id="T_9ce4c_level0_col1" class="col_heading level0 col1" >bidclose</th>
#       <th id="T_9ce4c_level0_col2" class="col_heading level0 col2" >bidhigh</th>
#       <th id="T_9ce4c_level0_col3" class="col_heading level0 col3" >bidlow</th>
# ...

# %%
pretty("api.get_candles('USD/JPY')")
api.get_candles('USD/JPY').head(5).style.format(precision = 4)
# Out:
# <style type="text/css">
# #T_f853c .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_f853c tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_f853c tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_f853c">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f853c_row0_col0" class="data row0 col0" >api.get_candles('USD/JPY')</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d59b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d59b1_level0_col0" class="col_heading level0 col0" >bidopen</th>
#       <th id="T_d59b1_level0_col1" class="col_heading level0 col1" >bidclose</th>
#       <th id="T_d59b1_level0_col2" class="col_heading level0 col2" >bidhigh</th>
#       <th id="T_d59b1_level0_col3" class="col_heading level0 col3" >bidlow</th>
# ...

# %%
pretty("api.get_candles('GBP/USD')")
api.get_candles('GBP/USD').head(5).style.format(precision = 4)
# Out:
# <style type="text/css">
# #T_78a1a .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_78a1a tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_78a1a tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_78a1a">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_78a1a_row0_col0" class="data row0 col0" >api.get_candles('GBP/USD')</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1f8f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f8f5_level0_col0" class="col_heading level0 col0" >bidopen</th>
#       <th id="T_1f8f5_level0_col1" class="col_heading level0 col1" >bidclose</th>
#       <th id="T_1f8f5_level0_col2" class="col_heading level0 col2" >bidhigh</th>
#       <th id="T_1f8f5_level0_col3" class="col_heading level0 col3" >bidlow</th>
# ...

# %% [markdown]
# <a name = 'intraday'></a>
#
# <hr class="dashed" style = 'color: #08CC5B'>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #6C07B2; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px; font-size: 14px; font-weight: 475; text-align: center; border-top: 2px solid #FFB83C; border-bottom: 2px solid #FFB83C;'  colspan="3"> |  <a href="#head">Top</a>  |  <a href="#historical">Historical Data</a>  |  <a href="#intraday">Intraday Frequency</a>   |  <a href="#time_period">Defining Time Period</a>  |  <a href="#indexes">Stock Indexes</a>  |  <a href="#commodities">Commodities</a>    <a href="#crypto">Cryptocurrencies</a>    <a href="#real_time">Real-Time Data</a>    </th>
# 		</tr>
# 	</table>
# </html>
#
# <hr class="dashed" style = 'color: #08CC5B'>

# %% [markdown]
# <a name = 'head'></a>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #A523FF; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;; text-align: center; border-bottom: 1.5px solid white;' colspan="3"><font size = 6>Intraday Frequency</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 15px; font-weight: 500; background-color: #FFB83C; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: left;' colspan="3">- <b><i>period</b></i>: string, the granularity of the data<br>- Must be one of: 'm1', 'm5', 'm15', 'm30', 'H1', 'H2', 'H3', 'H4', 'H6', 'H8', 'D1', 'W1', or 'M1'<br>- <b><i>number</b></i>: integer (default 10),
#         the number of candles to receive.</font></th>
# 		</tr>
# 	</table>
# </html>

# %%
# api = fxcmpy.fxcmpy(access_token = api_key, log_level = 'error')

# %%
pretty("api.get_candles('EUR/USD', period = 'D1'")
api.get_candles('EUR/USD', period = 'D1').head(5).style.format(precision = 4)
# Out:
# <style type="text/css">
# #T_05e4c .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_05e4c tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_05e4c tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_05e4c">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_05e4c_row0_col0" class="data row0 col0" >api.get_candles('EUR/USD', period = 'D1'</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_bd6b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd6b6_level0_col0" class="col_heading level0 col0" >bidopen</th>
#       <th id="T_bd6b6_level0_col1" class="col_heading level0 col1" >bidclose</th>
#       <th id="T_bd6b6_level0_col2" class="col_heading level0 col2" >bidhigh</th>
# ...

# %%
pretty("api.get_candles('EUR/USD', period = 'm1')")
api.get_candles('EUR/USD', period = 'm1').head(5).style.format(precision = 4)
# Out:
# <style type="text/css">
# #T_896b6 .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_896b6 tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_896b6 tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_896b6">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_896b6_row0_col0" class="data row0 col0" >api.get_candles('EUR/USD', period = 'm1')</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_1a473">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a473_level0_col0" class="col_heading level0 col0" >bidopen</th>
#       <th id="T_1a473_level0_col1" class="col_heading level0 col1" >bidclose</th>
#       <th id="T_1a473_level0_col2" class="col_heading level0 col2" >bidhigh</th>
# ...

# %%
import random
instrument = random.choice(trading_instruments)

# %%
pretty(f"api.get_candles('Copper', period = 'H3')")
api.get_candles('Copper', period = 'H3').head(5).style.format(precision = 4)
# Out:
# <style type="text/css">
# #T_8693f .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_8693f tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_8693f tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_8693f">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8693f_row0_col0" class="data row0 col0" >api.get_candles('Copper', period = 'H3')</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_85c48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85c48_level0_col0" class="col_heading level0 col0" >bidopen</th>
#       <th id="T_85c48_level0_col1" class="col_heading level0 col1" >bidclose</th>
#       <th id="T_85c48_level0_col2" class="col_heading level0 col2" >bidhigh</th>
# ...

# %% [markdown]
# <a name = 'time_period'></a>
#
# <hr class="dashed" style = 'color: #08CC5B'>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #6C07B2; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px; font-size: 14px; font-weight: 475; text-align: center; border-top: 2px solid #FFB83C; border-bottom: 2px solid #FFB83C;'  colspan="3"> |  <a href="#head">Top</a>  |  <a href="#historical">Historical Data</a>  |  <a href="#intraday">Intraday Frequency</a>   |  <a href="#time_period">Defining Time Period</a>  |  <a href="#indexes">Stock Indexes</a>  |  <a href="#commodities">Commodities</a>    <a href="#crypto">Cryptocurrencies</a>    <a href="#real_time">Real-Time Data</a>    </th>
# 		</tr>
# 	</table>
# </html>
#
# <hr class="dashed" style = 'color: #08CC5B'>

# %% [markdown]
# <a name = 'head'></a>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #A523FF; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;; text-align: center; border-bottom: 1.5px solid white;' colspan="3"><font size = 6>Defining a Time Period</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 15px; font-weight: 500; background-color: #FFB83C; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: left;' colspan="3">- by default, FXCM returns the 10 most recent time stamps<br>- this section will cover the ways to specify other parameters
# 		</font></th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 15px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="
				number = 10000)
# Out:
#                      bidopen  bidclose  bidhigh  bidlow  askopen  askclose  \
# date
# 2023-02-01 22:24:00     1.10      1.10     1.10    1.10     1.10      1.10
# 2023-02-01 22:25:00     1.10      1.10     1.10    1.10     1.10      1.10
# 2023-02-01 22:26:00     1.10      1.10     1.10    1.10     1.10      1.10
# 2023-02-01 22:27:00     1.10      1.10     1.10    1.10     1.10      1.10
# 2023-02-01 22:28:00     1.10      1.10     1.10    1.10     1.10      1.10
# ...                      ...       ...      ...     ...      ...       ...
# 2023-02-10 21:53:00     1.07      1.07     1.07    1.07     1.07      1.07
# 2023-02-10 21:54:00     1.07      1.07     1.07    1.07     1.07      1.07
# 2023-02-10 21:55:00     1.07      1.07     1.07    1.07     1.07      1.07
# 2023-02-10 21:56:00     1.07      1.07     1.07    1.07     1.07      1.07
# 2023-02-10 21:57:00     1.07      1.07     1.07    1.07     1.07      1.07
#
#                      askhigh  asklow  tickqty
# date
# ...

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>Getting data by the minute with start and end</b><br>- was able to get close to 16,000 records<br>- this is again the exact date range it would allow, no more<br>- this is more data than yfinance or Alpha Vantage allowed</th>
# 		</tr>
# 	</table>
# </html>

# %%
api.get_candles('EUR/USD', 
				period = 'm1', 
				start = '2023-01-26', 
				end = '2023-02-10')
# Out:
#                      bidopen  bidclose  bidhigh  bidlow  askopen  askclose  \
# date
# 2023-01-26 00:00:00     1.09      1.09     1.09    1.09     1.09      1.09
# 2023-01-26 00:01:00     1.09      1.09     1.09    1.09     1.09      1.09
# 2023-01-26 00:02:00     1.09      1.09     1.09    1.09     1.09      1.09
# 2023-01-26 00:03:00     1.09      1.09     1.09    1.09     1.09      1.09
# 2023-01-26 00:04:00     1.09      1.09     1.09    1.09     1.09      1.09
# ...                      ...       ...      ...     ...      ...       ...
# 2023-02-09 23:56:00     1.07      1.07     1.07    1.07     1.07      1.07
# 2023-02-09 23:57:00     1.07      1.07     1.07    1.07     1.07      1.07
# 2023-02-09 23:58:00     1.07      1.07     1.07    1.07     1.07      1.07
# 2023-02-09 23:59:00     1.07      1.07     1.07    1.07     1.07      1.07
# 2023-02-10 00:00:00     1.07      1.07     1.07    1.07     1.07      1.07
#
#                      askhigh  asklow  tickqty
# date
# ...

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>Selecting specific columns to import</b></th>
# 		</tr>
# 	</table>
# </html>

# %%
api.get_candles('EUR/USD', 
				period = 'D1', 
				start = '2001-01-01', 
				end = '2023-02-10',
			   columns = ['bidclose', 'askclose'])
# Out:
#                      bidclose  askclose
# date
# 2001-09-09 21:00:00      0.90      0.90
# 2001-09-10 21:00:00      0.91      0.91
# 2001-09-11 21:00:00      0.91      0.91
# 2001-09-12 21:00:00      0.91      0.91
# 2001-09-13 21:00:00      0.92      0.92
# ...                       ...       ...
# 2023-02-05 22:00:00      1.07      1.07
# 2023-02-06 22:00:00      1.07      1.07
# 2023-02-07 22:00:00      1.07      1.07
# 2023-02-08 22:00:00      1.07      1.07
# 2023-02-09 22:00:00      1.07      1.07
#
# [6213 rows x 2 columns]

# %% [markdown]
# <a name = 'indexes'></a>
#
# <hr class="dashed" style = 'color: #08CC5B'>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #6C07B2; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px; font-size: 14px; font-weight: 475; text-align: center; border-top: 2px solid #FFB83C; border-bottom: 2px solid #FFB83C;'  colspan="3"> |  <a href="#head">Top</a>  |  <a href="#historical">Historical Data</a>  |  <a href="#intraday">Intraday Frequency</a>   |  <a href="#time_period">Defining Time Period</a>  |  <a href="#indexes">Stock Indexes</a>  |  <a href="#commodities">Commodities</a>    <a href="#crypto">Cryptocurrencies</a>    <a href="#real_time">Real-Time Data</a>    </th>
# 		</tr>
# 	</table>
# </html>
#
# <hr class="dashed" style = 'color: #08CC5B'>

# %% [markdown]
# <a name = 'head'></a>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #A523FF; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;; text-align: center; border-bottom: 1.5px solid white;' colspan="3"><font size = 6>Historical Prices for Stock Indexes</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 15px; font-weight: 500; background-color: #FFB83C; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: left;' colspan="3"><center><img src = 'http://www.evanmarie.com/content/files/notebook_images/fxcm02.png' width = 500><br><img src = 'http://www.evanmarie.com/content/files/notebook_images/fxcm01.png' width = 500></center></font></th>
# 		</tr>
# 	</table>
# </html>

# %%
instruments = pd.Series(list(api.get_instruments()))
index_mask = instruments.str.contains(r'\d')
indexes_available = pd.Series(instruments.loc[index_mask]).reset_index()

# %%
head_tail_horz(indexes_available, 12, 'Indexes Available on FXCM')
# Out:
# <center><style type="text/css">
# #T_b1230 tr {
#   background-color: #A523FF;
#   color: white;
#   font-size: 18px;
#   font-weight: 600;
#   text-align: left;
#   padding: 3px 30px 3px 50px;
# }
# #T_b1230 td {
#   padding: 5px 10px 5px 10px;
#   width: 450px;
#   text-align: center;
# }
# </style>
# <table id="T_b1230">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b1230_row0_col0" class="data row0 col0" >Indexes Available on FXCM</td>
#     </tr>
#   </tbody>
# </table>
# <center><style type="text/css">
# #T_43ade caption {
#   background: #A523FF;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: 600;
# }
# #T_43ade td {
#   padding: 8px 10px 8px 10px;
# }
# </style>
# <table id="T_43ade" style='display:inline-block; vertical-align: top;'>
#   <caption>head(12)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b
th>
# 		</tr>
# 	</table>
# </html>

# %%
api.get_candles('GER30', 
				period = 'H1', 
				start = '2021-05-28', 
				end = '2023-02-10')
# Out:
#                       bidopen  bidclose   bidhigh    bidlow   askopen  \
# date
# 2021-05-28 00:00:00 15,428.93 15,462.56 15,471.50 15,458.56 15,430.03
# 2021-05-28 01:00:00 15,462.56 15,469.50 15,475.74 15,460.56 15,469.07
# 2021-05-28 02:00:00 15,469.50 15,465.67 15,470.74 15,456.56 15,470.80
# 2021-05-28 03:00:00 15,465.67 15,470.67 15,471.83 15,464.56 15,466.97
# 2021-05-28 04:00:00 15,470.67 15,478.83 15,479.74 15,461.45 15,471.97
# ...                       ...       ...       ...       ...       ...
# 2023-02-09 17:00:00 15,513.50 15,501.60 15,534.60 15,469.50 15,515.50
# 2023-02-09 18:00:00 15,501.00 15,481.50 15,509.50 15,470.00 15,503.00
# 2023-02-09 19:00:00 15,481.00 15,450.50 15,487.50 15,444.50 15,483.00
# 2023-02-09 20:00:00 15,450.10 15,433.80 15,450.60 15,403.50 15,452.10
# 2023-02-10 00:00:00 15,396.40 15,412.40 15,415.40 15,395.40 15,400.40
#
#                      askclose   askhigh    asklow  tickqty
# date
# ...

# %% [markdown]
# <a name = 'commodities'></a>
#
# <hr class="dashed" style = 'color: #08CC5B'>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #6C07B2; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px; font-size: 14px; font-weight: 475; text-align: center; border-top: 2px solid #FFB83C; border-bottom: 2px solid #FFB83C;'  colspan="3"> |  <a href="#head">Top</a>  |  <a href="#historical">Historical Data</a>  |  <a href="#intraday">Intraday Frequency</a>   |  <a href="#time_period">Defining Time Period</a>  |  <a href="#indexes">Stock Indexes</a>  |  <a href="#commodities">Commodities</a>    <a href="#crypto">Cryptocurrencies</a>    <a href="#real_time">Real-Time Data</a>    </th>
# 		</tr>
# 	</table>
# </html>
#
# <hr class="dashed" style = 'color: #08CC5B'>

# %% [markdown]
# <a name = 'head'></a>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #A523FF; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;; text-align: center; border-bottom: 1.5px solid white;' colspan="3"><font size = 6>Historical Prices for Commodities</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 15px; font-weight: 500; background-color: #FFB83C; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: left;' colspan="3">- Oil, Gold, Silver, Copper, Wheat, Corn<br>- FXCM is the best place for commodities information</font></th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>US Oil</b>: daily, max results</th>
# 		</tr>
# 	</table>
# </html>

# %%
api.get_candles('USOil', 
				period = 'D1', 
				number = 10000)
# Out:
#                      bidopen  bidclose  bidhigh  bidlow  askopen  askclose  \
# date
# 2001-09-10 00:00:00    27.95     27.63    28.00   27.57    27.95     27.63
# 2001-09-11 00:00:00    27.65     27.77    27.77   27.53    27.65     27.77
# 2001-09-17 00:00:00    29.00     28.81    29.25   28.30    29.00     28.81
# 2001-09-18 00:00:00    28.80     27.70    28.86   27.60    28.80     27.70
# 2001-09-19 00:00:00    27.67     26.72    27.95   25.80    27.67     26.72
# ...                      ...       ...      ...     ...      ...       ...
# 2023-02-05 22:00:00    73.22     74.42    74.50   72.23    73.26     74.45
# 2023-02-06 22:00:00    74.53     77.57    77.57   74.33    74.59     77.60
# 2023-02-07 22:00:00    77.45     78.47    78.55   77.07    77.51     78.50
# 2023-02-08 22:00:00    78.42     77.64    78.83   76.49    78.46     77.67
# 2023-02-09 22:00:00    77.66     79.81    80.31   77.45    77.70     79.84
#
#                      askhigh  asklow  tickqty
# date
# ...

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>Gold in USD</b>: daily data, max results</th>
# 		</tr>
# 	</table>
# </html>

# %%
api.get_candles('XAU/USD', 
				period = 'D1',
				number = 10000)
# Out:
#                      bidopen  bidclose  bidhigh   bidlow  askopen  askclose  \
# date
# 2001-09-09 21:00:00   273.25    271.75   273.60   270.95   273.25    271.75
# 2001-09-10 21:00:00   271.75    286.25   292.50   271.30   271.75    286.25
# 2001-09-11 21:00:00   286.75    278.25   292.50   276.75   286.75    278.25
# 2001-09-12 21:00:00   278.25    281.25   282.00   278.00   278.25    281.25
# 2001-09-13 21:00:00   281.25    285.55   290.00   279.00   281.25    285.55
# ...                      ...       ...      ...      ...      ...       ...
# 2023-02-05 22:00:00 1,860.83  1,867.24 1,881.23 1,860.36 1,861.89  1,867.54
# 2023-02-06 22:00:00 1,866.84  1,871.79 1,884.31 1,864.85 1,868.56  1,872.09
# 2023-02-07 22:00:00 1,872.39  1,875.35 1,886.23 1,868.91 1,873.94  1,875.65
# 2023-02-08 22:00:00 1,875.36  1,861.70 1,890.17 1,858.78 1,875.98  1,862.00
# 2023-02-09 22:00:00 1,861.18  1,865.26 1,872.07 1,852.59 1,862.72  1,865.91
#
#                      askhigh   asklow  tickqty
# ...

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>Siver in USD</b>: daily data, max results</th>
# 		</tr>
# 	</table>
# </html>

# %%
api.get_candles('XAG/USD', 
				period = 'D1',
				number = 10000)
# Out:
#                      bidopen  bidclose  bidhigh  bidlow  askopen  askclose  \
# date
#
font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 15px; font-weight: 500; background-color: #FFB83C; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: left;' colspan="3">- they used to have Ethereum and a few others, but those no longer work</font></th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>Bitcoin</b>: daily data, start and end dates</th>
# 		</tr>
# 	</table>
# </html>

# %%
api.get_candles('BTC/USD', 
				period = 'D1', 
				start = '2002-01-01', 
				end = '2023-02-10')
# Out:
#                       bidopen  bidclose   bidhigh    bidlow   askopen  \
# date
# 2017-12-15 22:00:00 19,900.00 19,900.00 19,900.00 19,900.00 19,901.00
# 2017-12-18 22:00:00 19,900.00 19,705.00 20,040.00 19,300.00 19,901.00
# 2017-12-19 22:00:00 19,705.00 18,555.00 19,340.00 19,310.00 19,706.00
# 2017-12-20 22:00:00 18,555.00 17,275.00 17,300.00 17,275.00 18,556.00
# 2017-12-21 22:00:00 17,275.00 15,680.00 16,330.00 15,915.00 17,276.00
# ...                       ...       ...       ...       ...       ...
# 2023-02-06 22:00:00 22,975.30 22,893.80 23,133.50 22,621.50 23,015.30
# 2023-02-07 22:00:00 22,894.30 23,177.80 23,330.50 22,621.50 22,934.30
# 2023-02-08 22:00:00 23,178.30 22,939.40 23,430.50 22,654.50 23,218.30
# 2023-02-09 22:00:00 22,939.00 21,839.30 22,992.20 21,678.20 22,979.00
# 2023-02-10 22:00:00 21,839.80 21,530.10 21,939.10 21,458.40 21,879.80
#
#                      askclose   askhigh    asklow  tickqty
# date
# ...

# %% [markdown]
# <a name = 'real_time'></a>
#
# <hr class="dashed" style = 'color: #08CC5B'>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #6C07B2; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px; font-size: 14px; font-weight: 475; text-align: center; border-top: 2px solid #FFB83C; border-bottom: 2px solid #FFB83C;'  colspan="3"> |  <a href="#head">Top</a>  |  <a href="#historical">Historical Data</a>  |  <a href="#intraday">Intraday Frequency</a>   |  <a href="#time_period">Defining Time Period</a>  |  <a href="#indexes">Stock Indexes</a>  |  <a href="#commodities">Commodities</a>    <a href="#crypto">Cryptocurrencies</a>    <a href="#real_time">Real-Time Data</a>    </th>
# 		</tr>
# 	</table>
# </html>
#
# <hr class="dashed" style = 'color: #08CC5B'>

# %% [markdown]
# <a name = 'head'></a>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #A523FF; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;; text-align: center; border-bottom: 1.5px solid white;' colspan="3"><font size = 6>High Frequency Real-Time Data</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 15px; font-weight: 500; background-color: #FFB83C; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: left;' colspan="3">- FXCM supports high frequency real-time data for some instruments<br>- this is something that usually costs a great deal for a subscription to access</font></th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b><i>api.subscribe_market_data()</b></i></b></th>
# 		</tr>
# 	</table>
# </html>

# %%
help(api.subscribe_market_data)
# Out:
# Help on method subscribe_market_data in module fxcmpy.fxcmpy:
#
# subscribe_market_data(symbol='', add_callbacks=()) method of fxcmpy.fxcmpy.fxcmpy instance
#     Stream the prices of an instrument.
#
#     Arguments:
#
#     symbol:  string,
#         the symbol of the instrument in question as given by
#         get_instruments().
#
#     add_callbacks: list of callables,
#         all methods in that list will be called for every incoming dataset
#         of the instrument. Such a method has to accept two positional
#         arguments, data and dataframe, say. The first should be a json like
#         object with the new price data received by the stream and the
#         second should be a Pandas DataFrame with the collected price data
#         as given by get_prices().

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>Subscribe to EUR/USD exchange data</b></th>
# 		</tr>
# 	</table>
# </html>

# %%
api.subscribe_market_data('EUR/USD')

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b><i>api.get_subscribed_symbols()</b></i></b> - get the current open subscriptions</th>
# 		</tr>
# 	</table>
# </html>

# %%
help(api.get_subscribed_symbols)
# Out:
# Help on method get_subscribed_symbols in module fxcmpy.fxcmpy:
#
# get_subscribed_symbols() method of fxcmpy.fxcmpy.fxcmpy instance
#     Returns a list of symbols for the subscribed instruments.

# %%
api.get_subscribed_symbols()
# Out:
# ['EUR/USD']

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b><i>api.get_last_price()</i></b> - get the last reported price for a symbol</th>
# 		</tr>
# 	</table>
# </html>

# %%
help(api.get_last_price)
# Out:
# Help on method get_last_price in module fxcmpy.fxcmpy:
#
# get_last_price(symbol) method of fxcmpy.fxcmpy.fxcmpy instance
#     Return the last prices of a given subscribed instrument.
#
#     Arguments:
#
#     symbol: string,
#         the symbol of the instrument as given by get_instruments().

# %%
pretty('The most recent price data for EUR/USD')
api.get_last_price('EUR/USD')
# Out:
# <style type="text/css">
# #T_3ec71 .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_3ec71 tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_3ec71 tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_3ec71">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3ec71_row0_col0" class="data row0 col0" >The most recent price data for EUR/USD</td>
#     </tr>
#   </tbody>
# </table>
# Bid    1.07
# Ask    1.07
# High   1.08
# Low    1.07
# Name: 2023-02-10 21:57:59.544000, dtype: float64

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b><i>api.get_prices()</i></b> - get all available data for a subscription since the subscription was started</th>
# 		</tr>
# 	</table>
# </html>

# %%
help(api.get_prices)
# Out:
# Help on method get_prices in module fxcmpy.fxcmpy:
#
# get_prices(symbol) method of fxcmpy.fxcmpy.fxcmpy instance
#     Return the prices of a given subscribed instrument.
#
#     Arguments:
#
#     symbol: string,
#         the symbol of the instrument as given by get_instruments().

# %%
api.get_prices('EUR/USD')
# Out:
#                          Bid  Ask  High  Low
# 2023-02-10 21:57:59.544 1.07 1.07  1.08 1.07

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3">Subscribing to Bitcoin also, because Euro is not updating</th>
# 		</tr>
# 	</table>
# </html>

# %%
api.subscribe_market_data('BTC/USD')

# %%
api.get_last_price('EUR/USD')
# Out:
# Bid    1.07
# Ask    1.07
# High   1.08
# Low    1.07
# Name: 2023-02-10 21:57:59.544000, dtype: float64

# %%
api.get_prices('BTC/USD')
# Out:
#                            Bid    Ask      High       Low
# 2023-02-10 21:58:30.932  21530  21564 23,470.50 21,458.25

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>Stream live data:</b></th>
# 		</tr>
# 	</table>
# </html>

# %%
import time
count = 0
pretty('Streaming EUR/USD data:')
while count < 10:
	time.sleep(1)
	print(api.get_last_price('EUR/USD').name, api.get_last_price('EUR/USD').Ask)
	count += 1
# Out:
# <style type="text/css">
# #T_5dc1e .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_5dc1e tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_5dc1e tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_5dc1e">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5dc1e_row0_col0" class="data row0 col0" >Streaming EUR/USD data:</td>
#     </tr>
#   </tbody>
# </table>
# 2023-02-10 21:57:59.544000 1.06803
# 2023-02-10 21:57:59.544000 1.06803
# 2023-02-10 21:57:59.544000 1.06803
# 2023-02-10 21:57:59.544000 1.06803
# 2023-02-10 21:57:59.544000 1.06803
# 2023-02-10 21:57:59.544000 1.06803
# 2023-02-10 21:57:59.544000 1.06803
# 2023-02-10 21:57:59.544000 1.06803
# 2023-02-10 21:57:59.544000 1.06803
# 2023-02-10 21:57:59.544000 1.06803

# %%
pretty('time.sleep()')
help(time.sleep)
# Out:
# <style type="text/css">
# #T_ab900 .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_ab900 tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_ab900 tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_ab900">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ab900_row0_col0" class="data row0 col0" >time.sleep()</td>
#     </tr>
#   </tbody>
# </table>
# Help on built-in function sleep in module time:
#
# sleep(...)
#     sleep(seconds)
#
#     Delay execution for a given number of seconds.  The argument may be
#     a floating point number for subsecond precision.

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>Function to stream the current ask price</b></th>
# 		</tr>
# 	</table>
# </html>

# %%
def stream_data(ticker, delay = 1, reps = 10):
	
	api.subscribe_market_data(ticker)
	import time
	
	pretty(f'Streaming {ticker} data:')
	count = 0
	while count < reps:
		time.sleep(delay)
		
		price = api.get_last_price(ticker).Ask
		timestamp = api.get_last_price(ticker).name
		pretty(f"{price:,.3f}", timestamp, fontsize = 3)
		
		count += 1
	api.subscribe_market_data(ticker)
	pretty(f'Transmission complete.')

# %%
stream_data('EUR/USD', delay = 1, reps = 3)
# Out:
# <style type="text/css">
# #T_e2abe .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_e2abe tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_e2abe tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_e2abe">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e2abe_row0_col0" class="data row0 col0" >Streaming EUR/USD data:</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1fbda .row0 {
#   background-color: #FFB83C;
#   color: black;
#   font-size: 3;
#   font-weight: 550;
#   text-align: left;
#   padding: 8px 10px 8px 10px;
# }
# #T_1fbda .row1 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 3;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_1fbda tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_1fbda tr {
#   border: 0.8px solid;
# ...

# %%
stream_data('BTC/USD', delay = 1, reps = 3)
# Out:
# <style type="text/css">
# #T_1cda4 .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_1cda4 tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_1cda4 tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_1cda4">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1cda4_row0_col0" class="data row0 col0" >Streaming BTC/USD data:</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8c70f .row0 {
#   background-color: #FFB83C;
#   color: black;
#   font-size: 3;
#   font-weight: 550;
#   text-align: left;
#   padding: 8px 10px 8px 10px;
# }
# #T_8c70f .row1 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 3;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_8c70f tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_8c70f tr {
#   border: 0.8px solid;
# ...

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 16px; font-weight: 500; background-color: #6C07B2; padding: 8px; line-height: 1.5; color:white; border-radius: 3px;; text-align: left;' colspan="3"><b>Unsubscribe from market data</b></th>
# 		</tr>
# 	</table>
# </html>

# %%
api.get_subscribed_symbols()
# Out:
# ['EUR/USD', 'BTC/USD']

# %%
stream_data('LCattleF', delay = 1, reps = 3)
# Out:
# <style type="text/css">
# #T_1351a .row0 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_1351a tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_1351a tr {
#   border: 0.8px solid;
#   border-color: black;
# }
# </style>
# <table id="T_1351a">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1351a_row0_col0" class="data row0 col0" >Streaming LCattleF data:</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3d2dd .row0 {
#   background-color: #FFB83C;
#   color: black;
#   font-size: 3;
#   font-weight: 550;
#   text-align: left;
#   padding: 8px 10px 8px 10px;
# }
# #T_3d2dd .row1 {
#   background-color: #A523FF;
#   color: white;
#   font-size: 3;
#   font-weight: bold;
#   text-align: left;
#   padding: 8px;
# }
# #T_3d2dd tbody {
#   border: 1px solid;
#   border-color: black;
# }
# #T_3d2dd tr {
#   border: 0.8px solid;
# ...

# %%
api.unsubscribe_market_data('EUR/USD')
api.unsubscribe_market_data('BTC/USD')

# %%
api.close()

# %% [markdown]
# <hr class="dashed" style = 'color: #08CC5B'>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #6C07B2; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px; font-size: 14px; font-weight: 475; text-align: center; border-top: 2px solid #FFB83C; border-bottom: 2px solid #FFB83C;'  colspan="3"> |  <a href="#head">Top</a>  |  <a href="#historical">Historical Data</a>  |  <a href="#intraday">Intraday Frequency</a>   |  <a href="#time_period">Defining Time Period</a>  |  <a href="#indexes">Stock Indexes</a>  |  <a href="#commodities">Commodities</a>    <a href="#crypto">Cryptocurrencies</a>    <a href="#real_time">Real-Time Data</a>    </th>
# 		</tr>
# 	</table>
# </html>
#
# <hr class="dashed" style = 'color: #08CC5B'>
