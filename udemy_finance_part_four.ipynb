# %% [markdown]
# <a name = 'head'></a>
#
# <hr class="dashed" style = 'color: #04B2D9'>
#
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #04D94F; padding: 5px 5px 3px 5px; line-height: 1.5; color:white; border-radius: 3px; font-size: 14px; font-weight: 475; text-align: center;'  colspan="3"> |  <a href="#head">Top</a>  |  <a href="#link">Link</a>  |  <a href="#link">Link</a>   |  <a href="#link">Link</a>  |  <a href="#link">Link</a> |  <a href="#link">Link</a>  |  <a href="#link">Link</a>  |  <a href="#link">Link</a>  |  </font></th>
# 		</tr>
# 	</table>
# </html>
#
# <hr class="dashed" style = 'color: #04B2D9'>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #F2059F; padding: 8; line-height: 1.5; color:white; border-radius: 3px;; text-align: center; border-top: 2px solid white; border-bottom: 3px solid #04B2D9; border-top: 3px solid #04B2D9;font-size: 33px;' colspan="3">Finance APIs: OANDA</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #F2CB05; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:black;border-radius: 3px; text-align: left;border-bottom: 3px solid #04B2D9; border-top: 3px solid white;' colspan="3">- trading platform that trades CFDs, contracts for differences<br>- risky financial derivatives<br>- over 70% of retail investors lose money when trading with OANDA
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 17px; font-weight: 525; background-color: #F28705; padding: 8px; line-height: 1.5; color:white; border-radius: 3px; text-align: center; border-bottom: 3px solid #04B2D9' colspan="3">|  <a href = 'https://trade.oanda.com/'>OANDA Site</a>  |  <a href = 'https://www.oanda.com/demo-account/tpa/personal_token'>OANDA API</a>  |</font></th>
# 		</tr>
# 	</table>
# </html>
#
# <html>
# 	<table>
# 	<tr style = 'background-color: #04D94F; border-top: 2px solid #F2CB05; border-bottom: 2px solid #F2CB05; color: white;' colspan = 3>
# 			<td style = 'font-size: 13px; text-align: center;' colspan = 5><b>Evan Marie online</b>:  |  <a href = 'https://www.evanmarie.com/'>EvanMarie.com</a>|  <a href = 'mailto:evanmarie@proton.me'>EvanMarie@Proton.me</a>  |  <a href = 'https://www.linkedin.com/in/evanmarie/'>Linked In</a>  |  <a href = 'https://github.com/EvanMarie'>GitHub</a>   |  <a href = 'https://huggingface.co/EvanMarie'>Hugging Face</a>  |  <a href = 'https://sigmoid.social/@EvanMarie'>Mastadon</a>  |  <a href = 'https://jovian.ai/evanmarie'>Jovian.ai</a>  |  <a href = 'https://www.tiktok.com/@evanmarie_123'>TikTok</a>  |  <a href = 'https://www.codewars.com/users/EvanMarie'>CodeWars</a>  |  <b>Discord ⇨ ✨ EvanMarie ✨#6114</b>  |
# 			</td></tr>
# 	</table>
# </html>

# %%
from helpers_bright import *
import_all()
import tpqoa
plt.style.use('bright.mplstyle')

# %%
# %%html
# <style>
# a:link {color: purple !important; font-weight: 600 !important;}
# a:visited {color: purple !important; font-weight: 600 !important;}
# </style>
# Out:
# <style>
# a:link {color: purple !important; font-weight: 600 !important;}
# a:visited {color: purple !important; font-weight: 600 !important;}
# </style>

# %%
api = tpqoa.tpqoa("./OANDA/oanda.cfg")

# %%
instruments = pd.DataFrame([x[0] for x in api.get_instruments()])

# %%
header_text('OANDA Symbols')
multi([(instruments.iloc[0:17], '1'), 
	   (instruments.iloc[17:34], '2'), 
	   (instruments.iloc[34:51], '3'), 
	   (instruments.iloc[51:-1], '4')])
# Out:
# <center><style type="text/css">
# #T_55377 tr {
#   background-color: #F28705;
#   color: black;
#   font-size: 15px;
#   font-weight: 600;
#   text-align: left;
#   padding: 3px 30px 3px 50px;
# }
# #T_55377 td {
#   padding: 5px 10px 5px 10px;
#   width: 375px;
#   text-align: center;
# }
# </style>
# <table id="T_55377">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_55377_row0_col0" class="data row0 col0" >OANDA Symbols</td>
#     </tr>
#   </tbody>
# </table>
# <center><style type="text/css">
# #T_2f5b9 caption {
#   background: #F28705;
#   border-radius: 3px;
#   padding: 5px;
#   color: black;
#   font-size: 15px;
#   font-weight: 600;
# }
# #T_2f5b9 td {
#   padding: 8px 10px 8px 10px;
# }
# </style>
# <table id="T_2f5b9" style='display:inline-block; vertical-align: top;'>
#   <caption>1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f5b9_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f5b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f5b9_row0_col0" class="data row0 col0" >AUD/CAD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f5b9_row1_col0" class="data row1 col0" >AUD/CHF</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f5b9_row2_col0" class="data row2 col0" >AUD/HKD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f5b9_row3_col0" class="data row3 col0" >AUD/JPY</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2f5b9_row4_col0" class="data row4 col0" >AUD/NZD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2f5b9_row5_col0" class="data row5 col0" >AUD/SGD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2f5b9_row6_col0" class="data row6 col0" >AUD/USD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2f5b9_row7_col0" class="data row7 col0" >CAD/CHF</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2f5b9_row8_col0" class="data row8 col0" >CAD/HKD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2f5b9_row9_col0" class="data row9 col0" >CAD/JPY</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2f5b9_row10_col0" class="data row10 col0" >CAD/SGD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2f5b9_row11_col0" class="data row11 col0" >CHF/HKD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2f5b9_row12_col0" class="data row12 col0" >CHF/JPY</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2f5b9_row13_col0" class="data row13 col0" >CHF/ZAR</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2f5b9_row14_col0" class="data row14 col0" >EUR/AUD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2f5b9_row15_col0" class="data row15 col0" >EUR/CAD</td>
#     </tr>
#     <tr>
#       <th id="T_2f5b9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2f5b9_row16_col0" class="data row16 col0" >EUR/CHF</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_2c11f caption {
#   background: #F28705;
#   border-radius: 3px;
#   padding: 5px;
#   color: black;
#   font-size: 15px;
#   font-weight: 600;
# }
# #T_2c11f td {
#   padding: 8px 10px 8px 10px;
# }
# </style>
# <table id="T_2c11f" style='display:inline-block; vertical-align: top;'>
#   <caption>2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c11f_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c11f_level0_row0" class="row_heading level0 row0" >17</th>
#       <td id="T_2c11f_row0_col0" class="data row0 col0" >EUR/CZK</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row1" class="row_heading level0 row1" >18</th>
#       <td id="T_2c11f_row1_col0" class="data row1 col0" >EUR/DKK</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_2c11f_row2_col0" class="data row2 col0" >EUR/GBP</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row3" class="row_heading level0 row3" >20</th>
#       <td id="T_2c11f_row3_col0" class="data row3 col0" >EUR/HKD</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row4" class="row_heading level0 row4" >21</th>
#       <td id="T_2c11f_row4_col0" class="data row4 col0" >EUR/HUF</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row5" class="row_heading level0 row5" >22</th>
#       <td id="T_2c11f_row5_col0" class="data row5 col0" >EUR/JPY</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row6" class="row_heading level0 row6" >23</th>
#       <td id="T_2c11f_row6_col0" class="data row6 col0" >EUR/NOK</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row7" class="row_heading level0 row7" >24</th>
#       <td id="T_2c11f_row7_col0" class="data row7 col0" >EUR/NZD</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row8" class="row_heading level0 row8" >25</th>
#       <td id="T_2c11f_row8_col0" class="data row8 col0" >EUR/PLN</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row9" class="row_heading level0 row9" >26</th>
#       <td id="T_2c11f_row9_col0" class="data row9 col0" >EUR/SEK</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row10" class="row_heading level0 row10" >27</th>
#       <td id="T_2c11f_row10_col0" class="data row10 col0" >EUR/SGD</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row11" class="row_heading level0 row11" >28</th>
#       <td id="T_2c11f_row11_col0" class="data row11 col0" >EUR/TRY</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row12" class="row_heading level0 row12" >29</th>
#       <td id="T_2c11f_row12_col0" class="data row12 col0" >EUR/USD</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row13" class="row_heading level0 row13" >30</th>
#       <td id="T_2c11f_row13_col0" class="data row13 col0" >EUR/ZAR</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row14" class="row_heading level0 row14" >31</th>
#       <td id="T_2c11f_row14_col0" class="data row14 col0" >GBP/AUD</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row15" class="row_heading level0 row15" >32</th>
#       <td id="T_2c11f_row15_col0" class="data row15 col0" >GBP/CAD</td>
#     </tr>
#     <tr>
#       <th id="T_2c11f_level0_row16" class="row_heading level0 row16" >33</th>
#       <td id="T_2c11f_row16_col0" class="data row16 col0" >GBP/CHF</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_b38b9 caption {
#   background: #F28705;
#   border-radius: 3px;
#   padding: 5px;
#   color: black;
#   font-size: 15px;
#   font-weight: 600;
# }
# #T_b38b9 td {
#   padding: 8px 10px 8px 10px;
# }
# </style>
# <table id="T_b38b9" style='display:inline-block; vertical-align: top;'>
#   <caption>3</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b38b9_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b38b9_level0_row0" class="row_heading level0 row0" >34</th>
#       <td id="T_b38b9_row0_col0" class="data row0 col0" >GBP/HKD</td>
#     </tr>
#     <tr>
#       <th id="T_b38b9_level0_row1" class="row_heading level0 row1" >35</th>
#       <td id="T_b38b9_row1_col0" class="data row1 col0" >GBP/JPY</td>
#     </tr>
#     <tr>
#       <th id="T_b38b9_level0_row2" class="row_heading level0 row2" >36</th>
#       <td id="T_b38b9_row2_col0" class="data row2 col0" >GBP/NZD</td>
#     </tr>
#     <tr>
#       <th id="T_b38b9_level0_row3" class="row_heading level0 row3" >37</th>
#       <td id="T_b38b9_row3_col0" class="data row3 col0" >GBP/PLN</td>
#     </tr>
#     <tr>
#       <th id="T_b38b9_level0_row4" class="row_heading level0 row4" >38</th>
#       <td id="T_b38b9_row4_col0" class="data row4 col0" >GBP/SGD</td>
#     <

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #F2059F; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px; text-align: center; border-bottom: 3px solid #F2CB05; border-top: 3px solid #F2CB05;' colspan="3"><font size = 6>Historical Data</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #04B2D9; padding: 8px; line-height: 1.5; color:white; border-radius: 3px; text-align: left; border-bottom: 3px solid #F2CB05; border-top: 3px solid #F2CB05' colspan="3">- Explanations</font></th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 19px; font-weight: 525; background-color: #F2059F; padding: 8px; line-height: 1.5; color:white; border-radius: 3px; text-align: left; border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Title</font></th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<th style = 'font-size: 14px; font-weight: 500; background-color: #F2CB05; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:black;border-radius: 3px; text-align: left;border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Text
# 		</tr></th>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #04D94F; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: left;border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Text</th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #04B2D9; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:white;border-radius: 3px; text-align: left;border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Text</th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #F28705; padding: 8px; line-height: 1.5; color:white; border-radius: 3px; text-align: left;border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Text</th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 19px; font-weight: 525; background-color: #F2059F; padding: 8px; line-height: 1.5; color:white; border-radius: 3px; text-align: left; border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Title</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #04B2D9; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:white;border-radius: 3px; text-align: left;border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Text</th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #04D94F; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: left;border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Text</th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #F2CB05; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:black;border-radius: 3px; text-align: left;border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Text
# 		</tr></th>
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #F28705; padding: 8px; line-height: 1.5; color:white; border-radius: 3px; text-align: left;border-bottom: 3px solid white; border-top: 3px solid white;' colspan="3">Section Text</th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'background-color: #F2059F; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px; text-align: center; border-bottom: 3px solid #F2CB05; border-top: 3px solid #F2CB05;' colspan="3"><font size = 6>Section Title</font></th>
# 		</tr>
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #04B2D9; padding: 8px; line-height: 1.5; color:white; border-radius: 3px; text-align: left; border-bottom: 3px solid #F2CB05; border-top: 3px solid #F2CB05' colspan="3">- Explanations</font></th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 20px; font-weight: 500; background-color: #04D94F; padding: 8px; line-height: 1.5; color:black; border-radius: 3px; text-align: center; border-bottom: 3px solid #F2CB05; border-top: 3px solid #F2CB05;' colspan="3">Strong Topic</font></th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 14px; font-weight: 500; background-color: #F2CB05; padding: 5px 5px 3px 10px; line-height: 1.5; text-align: left; color:black; border-radius: 3px; text-align: left;border-bottom: 3px solid #04B2D9; border-top: 3px solid #04B2D9;' colspan="3"><b><i>comment</i></b></font></th>
# 		</tr>
# 	</table>
# </html>

# %% [markdown]
# <html>
# 	<table style="width:100%;">
# 		<tr>
# 			<th style = 'font-size: 17px; font-weight: 525; background-color: #F28705; padding: 8px; line-height: 1.5; color:white; border-radius: 3px; text-align: left; border-top: 3px solid #04D94F; border-bottom: 3px solid #04D94F;' colspan="3">Topic</font></th>
# 		</tr>
# 	</table>
# </html>
